# %%
import pandas as pd

# %%
data={
    "a":[12,72,32,4],
    "b":[45,56,46,76],
    }
df=pd.DataFrame(data)
df.head()

# %%
df.head()
# Out:
#     a   b
# 0  12  45
# 1  32  56
# 2  32  46
# 3   4  76

# %%
df.tail()
# Out:
#     a   b
# 0  12  45
# 1  72  56
# 2  32  46
# 3   4  76

# %%
df.count()
# Out:
# a    4
# b    4
# dtype: int64

# %%
df.sum()
# Out:
# a     80
# b    223
# dtype: int64

# %%
df.mean()
# Out:
# a    30.00
# b    55.75
# dtype: float64

# %%
df.median()
# Out:
# a    22.0
# b    51.0
# dtype: float64

# %%
df.mode()
# Out:
#     a   b
# 0   4  45
# 1  12  46
# 2  32  56
# 3  72  76

# %%
df.std()
# Out:
# a    30.375429
# b    14.384598
# dtype: float64

# %%
df.min()
# Out:
# a     4
# b    45
# dtype: int64

# %%
df.max()
# Out:
# a    72
# b    76
# dtype: int64

# %%
df.describe()
# Out:
#                a          b
# count   4.000000   4.000000
# mean   30.000000  55.750000
# std    30.375429  14.384598
# min     4.000000  45.000000
# 25%    10.000000  45.750000
# 50%    22.000000  51.000000
# 75%    42.000000  61.000000
# max    72.000000  76.000000

# %%
df.abs()
# Out:
#     a   b
# 0  12  45
# 1  72  56
# 2  32  46
# 3   4  76

# %%
df.prod()
# Out:
# a     110592
# b    8809920
# dtype: int64

# %%
df.sum()
# Out:
# a    120
# b    223
# dtype: int64

# %%
df.cumsum()
# Out:
#      a    b
# 0   12   45
# 1   84  101
# 2  116  147
# 3  120  223

# %%
df.cumprod()
# Out:
#         a        b
# 0      12       45
# 1     864     2520
# 2   27648   115920
# 3  110592  8809920
